# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("bank_customer_churn.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dummy = ['Geography','Gender']
data = pd.get_dummies(df,columns = dummy,drop_first = True)
X = data.drop(['Exited','Surname','CustomerId','RowNumber'], axis = 1)
Y = data['Exited']
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# 5             645   44       8  113755.78              2          1
# 6             822   50       7       0.00              2          1
# 7             376   29       4  115046.74              4          1
# 8             501   44       4  142051.07              2          0
# 9             684   27       2  134603.88              1          1
# 10            528   31       6  102016.72              2          0
# 11            497   24       3       0.00              2          1
# 12            476   34      10       0.00              2          1
# ...

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.75)
lpc = MLPClassifier(solver = 'lbfgs',alpha = 1e-5, hidden_layer_sizes=(5,2),random_state = 1)
lpc.fit(X_train,Y_train)
predict = lpc.predict(X_test)
print ("The accuracy is %.3f" % accuracy_score(Y_test, predict))
# Out:
# D:\AAAAAAAAAAAAAA\anaconda\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# The accuracy is 0.854

# %%
# Pandas 
import pandas as pd
import numpy as np

# matplotlib
import matplotlib.pylab as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection  import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
layer = [1,2,3]
unit = [2,3,4,5]
for layers in layer:
    accuracy = []
    for units in unit:
        lpc = MLPClassifier(solver = 'lbfgs',alpha = 1e-5, hidden_layer_sizes=(units,layers),random_state = 1)
        cross_fold_accuracies = cross_val_score(lpc, X, Y, scoring = "accuracy", cv = 5)
        cross_fold_accuracy = np.mean(cross_fold_accuracies)
        accuracy.append(cross_fold_accuracy)
        print("The accuracy of %d layers and %d units is: %.5f" %(layers,units, cross_fold_accuracy))
    plt.plot(unit, accuracy,label = str(layers)+"layers")
plt.legend()
plt.show()
# Out:
# The accuracy of 1 layers and 2 units is: 0.83290
# The accuracy of 1 layers and 3 units is: 0.80610
# The accuracy of 1 layers and 4 units is: 0.79630
# The accuracy of 1 layers and 5 units is: 0.84610
# The accuracy of 2 layers and 2 units is: 0.84150
# The accuracy of 2 layers and 3 units is: 0.84440
# The accuracy of 2 layers and 4 units is: 0.86040
# The accuracy of 2 layers and 5 units is: 0.86090
# The accuracy of 3 layers and 2 units is: 0.83330
# The accuracy of 3 layers and 3 units is: 0.84380
# The accuracy of 3 layers and 4 units is: 0.86030
# The accuracy of 3 layers and 5 units is: 0.86170

# %%
tree = DecisionTreeClassifier()
reg = LogisticRegression()
lpc = MLPClassifier(solver = 'lbfgs',alpha = 1e-5, hidden_layer_sizes=(5,2),random_state = 1)

models = [tree,reg,lpc]
for model in models:
    model.fit(X_train, Y_train)

    # Get probabilities for my tree on the test data
    Y_test_probabilities = model.predict_proba(X_test)[:, 1]
    
    # Get TPR and FPR from my tree
    fpr, tpr, thresholds = roc_curve(Y_test, Y_test_probabilities)

    # Get area under the ROC curve
    auc = roc_auc_score(Y_test, Y_test_probabilities)
    
    # I'm going to round the AUC to 2 decimal places
    auc = round(auc, 2)
    
    # Plot my ROC curve and label it with my depth and AUROC
    plt.plot(fpr, tpr, label = "AUC=" + str(auc))

# Add the random line and legend
plt.plot([0,1], [0,1], 'k--', label="Random")
plt.legend(loc=2)

# Show the plot
plt.show()

# %% [markdown]
# #### conclution: MLPClassifier has a better performance than both the logistic regression and the classification tree. And the best layer is 2, the best unit number is 5
